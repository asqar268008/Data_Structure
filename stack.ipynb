# %%
from collections import deque
stack = deque([1,2,3,4,5,6,7,8,15])
stack
# Out:
# deque([1, 2, 3, 4, 5, 6, 7, 8, 15])

# %%
stack.append(9)
stack
# Out:
# deque([1, 2, 3, 4, 5, 6, 7, 8, 15, 9])

# %%
stack.appendleft(0)
stack
# Out:
# deque([0, 1, 2, 3, 4, 5, 6, 7, 8, 15, 9])

# %%
stack.insert(2,100)
stack
# Out:
# deque([0, 1, 100, 2, 3, 4, 5, 6, 7, 8, 15, 9])

# %%
stack.pop()
stack
# Out:
# deque([0, 1, 100, 2, 3, 4, 5, 6, 7, 8, 15])

# %%
stack.pop()
stack
# Out:
# deque([0, 1, 100, 2, 3, 4, 5, 6, 7, 8])
