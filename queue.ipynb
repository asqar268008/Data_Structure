# %%
from queue import Queue
q = Queue()

# %%
q.put(1)
q.put(2)
q

# %%
a = q.get()
a
# Out:
# 1

# %%
q.empty()
# Out:
# False

# %%
q = Queue(maxsize=12)
for i in range(0,11):
    q.put(i)

# %%
q.full()
# Out:
# False

# %%
q.put(100)

# %%
q.full()
# Out:
# True

# %%
a = q.get()
a
# Out:
# 1
