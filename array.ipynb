# %%
from array import *
arr = array('i',[1,2,3,4,5])
arr
# Out:
# array('i', [1, 2, 3, 4, 5])

# %%
arr2 = array('f',[1.,25,.58,45.23,78,9])
arr2
# Out:
# array('f', [1.0, 25.0, 0.5799999833106995, 45.22999954223633, 78.0, 9.0])

# %% [markdown]
# # Access

# %%
arr[1]
# Out:
# 2

# %% [markdown]
# # Insertion

# %%
arr.append(41)
arr
# Out:
# array('i', [1, 2, 3, 4, 5, 41])

# %%
arr.insert(0, 4)
arr
# Out:
# array('i', [4, 4, 1, 2, 3, 4, 5, 41])

# %% [markdown]
# # Delection

# %%
arr.pop()
arr
# Out:
# array('i', [4, 4, 1, 2, 3, 4, 5])

# %%
arr.remove(4)
arr
# Out:
# array('i', [4, 1, 2, 3, 4, 5])

# %% [markdown]
# # Search

# %%
for i in range(0,len(arr)):
    if arr[i] == 7:
        print("True")
        break
else:
    print("False")
# Out:
# False
